# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import seaborn as sns
from scipy.stats import kstest, zscore
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
# %matplotlib inline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import math

# %% [markdown]
# 1. Imports
# 2. Load Data
# 3. Data Cleaning
# 4. Exploratory Data Analysis
# 5. Feature Engineering
# 6. Define Features and Target
# 7. Train/Test Split
# 8. Feature Scaling
# 9. Model Training
# 10. Model Evaluation

# %%
df = pd.read_csv("/Users/victoriacano/Downloads/red_ml_final.csv", encoding="cp1252", sep=";")
df.dtypes

df = df.drop(columns=["name", "region", "variety"])
df
# Out:
#             country                     winery  rating  numberofratings  \
# 0            France      Château La Providence     4.2              100
# 1            France         Château Mont-Redon     4.3              100
# 2             Italy                 Renzo Masi     3.9              100
# 3             Italy                 Cavalchina     3.5              100
# 4           Austria                Markowitsch     3.9              100
# ...             ...                        ...     ...              ...
# 8661  United States       Michael David Winery     3.8              994
# 8662          Italy                Le Mortelle     4.0              995
# 8663         France  Château Cambon La Pelouse     3.7              996
# 8664      Australia                Yellow Tail     3.5              998
# 8665      Argentina                  Salentein     3.4              999
#
#       price  year                          name_clean  \
# 0     95.00  2011                        pomerol 2011
# 1     15.50  2017                          lirac 2017
# 2      7.45  2015  erta e china rosso di toscana 2015
# 3      8.72  2019                      bardolino 2019
# 4     29.15  2016      ried scheibner pinot noir 2016
# ...     ...   ...                                 ...
# 8661  16.47  2016                6th sense syrah 2016
# 8662  20.09  2016     botrosecco maremma toscana 2016
# 8663  23.95  2010                     haut medoc 2010
# 8664   6.21  2019                         shiraz 2019
# 8665   7.88  2016    portillo cabernet sauvignon 2016
#
#                  region_clean          variety_ml
# 0                     pomerol      Bordeaux Blend
# 1                       lirac         Rhône Blend
# 2                     toscana     Unspecified Red
# 3                   bardolino             Corvina
# 4                   carnuntum          Pinot Noir
# ...                       ...                 ...
# 8661                     lodi               Syrah
# 8662          maremma toscana     Unspecified Red
# 8663               haut medoc      Bordeaux Blend
# 8664  south eastern australia              Shiraz
# 8665                  tunuyan  Cabernet Sauvignon
#
# [8666 rows x 9 columns]

# %% [markdown]
# ### DATA CLEANING

# %%
#Cleaning and validating data 
df["year"] = pd.to_numeric(df["year"], errors="coerce")
df = df.dropna(subset=["year"])
df["year"].value_counts()


df["wine_age"] = 2026 - df["year"]

df["wine_age"].astype("Int64")
df_numeric = df.select_dtypes(include='number')

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS TO UNDERSTAND CORRELATION BETWEEN VARIABLES

# %% [markdown]
# In Machine Learning we want features to be highly correlated with the target but not between themselves since high correlation among features themselves can lead to redundancy and instability in model, potentially degrading performance. In order to evaluate the correlation between variables we will carry out a quick EDA that will help us evaluate not only the relationship between features themselves but also with the target

# %% [markdown]
# #### Scatterplot

# %%
sns.pairplot(df_numeric, hue="rating")

# %% [markdown]
# #### Correlation Matrix

# %%
#Correlation Matrix 

corr=np.abs(df_numeric.corr()) # corr(x,y) = corr(y, x), corr(x,x) = 1

#Set up mask for triangle representation
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,  vmax=1,square=True, linewidths=.5, cbar_kws={"shrink": .5},annot = corr)

plt.show()

# %% [markdown]
# Interpretation:
# - Price appears to be the strongest predictor
# - Year might also contribute some predictive power
# - NumberOfRatings likely adds very little information
# - Features are not strongly correlated with each other

# %% [markdown]
# #### Pearson Correlation Coefficient

# %%
df.corr(method='pearson', min_periods=1, numeric_only=True)
# Out:
#                    rating  numberofratings     price      year  wine_age
# rating           1.000000         0.070317  0.451251 -0.343491  0.343491
# numberofratings  0.070317         1.000000  0.005823 -0.025555  0.025555
# price            0.451251         0.005823  1.000000 -0.363914  0.363914
# year            -0.343491        -0.025555 -0.363914  1.000000 -1.000000
# wine_age         0.343491         0.025555  0.363914 -1.000000  1.000000

# %% [markdown]
# Insight: Our target is ratings (predict ratings based on certain features) so we want variables/that have a high absolute correlation with it.
#
# - Price and Year are the variables that have the strongest relationship with ratings

# %% [markdown]
# ### NORMALISING PRICE AND NUMBER OF RATINGS

# %% [markdown]
# #### Visual and Statistical Inspection

# %%
#Checking for normality visually and statistically for numerical columns
#Visual Inspection: Histogram

df_numeric.hist(figsize=(15, 29), bins=60, xlabelsize=10, ylabelsize=10)

#Statistical Inspection: K-S test
def ks_test(df):
    for col in df.columns:
        data = df[col].dropna()
        standardized = (data - data.mean()) / data.std()

        ks_test_statistic, ks_p_value = stats.kstest(standardized, 'norm')

        if ks_p_value < 0.05:
            print(f"{col}: distribution is significantly different from normal (p = {ks_p_value:})(t-statistic:{ks_test_statistic})")
        else:
            print(f"{col}: distribution is NOT significantly different from normal (p = {ks_p_value:})(t-statistic:{ks_test_statistic})")

ks_test(df_numeric)
# Out:
# rating: distribution is significantly different from normal (p = 8.216473287105949e-47)(t-statistic:0.07846577286920048)
# numberofratings: distribution is significantly different from normal (p = 0.0)(t-statistic:0.3268449361959398)
# price: distribution is significantly different from normal (p = 0.0)(t-statistic:0.3400578210788768)
# year: distribution is significantly different from normal (p = 0.0)(t-statistic:0.2087121674413101)
# wine_age: distribution is significantly different from normal (p = 0.0)(t-statistic:0.20871216744129945)

# %% [markdown]
# #### Transforming Data to be Normally Distributed
#
# Based on our visualisations and tests, we can see that our features and target are significantly different from a normal distribution, thus we need to normalise our data. This normalisation aids in statistical analysis and modelling.
#
# There are different ways to transform data, for our project we will use the following transformations:
#
# 1. **Log transformation** for Price, Number of Ratings, Wine Age since they are both right-skewed

# %%
#Log transformation for Price and Number of Ratings and Standardising them: 

#Price
log_transformed_price = np.log1p(df["price"])
standardized_log_price = (log_transformed_price - log_transformed_price.mean()) / log_transformed_price.std()

fig, axes = plt.subplots(1,3, figsize=(30,10))
sns.histplot(df['price'], kde=True, bins=50, color="skyblue", ax=axes[0])
sns.histplot(log_transformed_price, kde=True, bins=50, color="skyblue", ax=axes[1])

# Plotting histogram for transformed 'Price'
sns.histplot(standardized_log_price, kde=True, bins=50, color="skyblue", ax=axes[2])
plt.tight_layout()
plt.show()


#Number of Ratings

log_transformed_nratings = np.log1p(df["numberofratings"])
standardized_log_nratings = (log_transformed_nratings - log_transformed_nratings.mean()) / log_transformed_nratings.std()

fig, axes = plt.subplots(1,3, figsize=(30,10))
sns.histplot(df['numberofratings'], kde=True, bins=50, color="skyblue", ax=axes[0])
sns.histplot(log_transformed_nratings, kde=True, bins=50, color="skyblue", ax=axes[1])

# Plotting histogram for transformed 'Price'
sns.histplot(standardized_log_nratings, kde=True, bins=50, color="skyblue", ax=axes[2])
plt.tight_layout()
plt.show()



#Wine Age

log_transformed_wineage = np.log1p(df["wine_age"])
standardized_log_wineage = (log_transformed_wineage - log_transformed_wineage.mean()) / log_transformed_wineage.std()

fig, axes = plt.subplots(1,3, figsize=(30,10))
sns.histplot(df['wine_age'], kde=True, bins=50, color="skyblue", ax=axes[0])
sns.histplot(log_transformed_wineage, kde=True, bins=50, color="skyblue", ax=axes[1])

# Plotting histogram for transformed 'Wine Age'
sns.histplot(standardized_log_wineage, kde=True, bins=50, color="skyblue", ax=axes[2])
plt.tight_layout()
plt.show()


#Rating

log_transformed_rating = np.log1p(df["rating"])
standardized_log_rating = (log_transformed_rating - log_transformed_rating.mean()) / log_transformed_rating.std()

fig, axes = plt.subplots(1,3, figsize=(30,10))
sns.histplot(df["rating"], kde=True, bins=50, color="skyblue", ax=axes[0])
sns.histplot(log_transformed_rating, kde=True, bins=50, color="skyblue", ax=axes[1])

# Plotting histogram for transformed 'Wine Age'
sns.histplot(standardized_log_rating, kde=True, bins=50, color="skyblue", ax=axes[2])
plt.tight_layout()
plt.show()

# %%
#Re-assessing Distribution: after applying the transformation we want to assess the distribution again

# Q-Q plot for transformed 'Price'
stats.probplot(standardized_log_price, plot=plt);
ks_test_statistic_after_transformation, ks_p_value_after_transformation = stats.kstest(standardized_log_price, 'norm')
ks_test_statistic_after_transformation, ks_p_value_after_transformation

#Lower ks test statistic after transformation --> closer to normal distribution
# Out:
# (np.float64(0.09149448225732748), np.float64(1.6021098453995957e-63))

# %%
# Q-Q plot for transformed 'NumberOfRatings'
stats.probplot(standardized_log_nratings, plot=plt);
ks_test_statistic_after_transformation_nr, ks_p_value_after_transformation_nr = stats.kstest(standardized_log_nratings, 'norm')
ks_test_statistic_after_transformation_nr, ks_p_value_after_transformation_nr

#Lower ks test statistic after transformation --> closer to normal distribution
# Out:
# (np.float64(0.056278748728268956), np.float64(2.8163753066598106e-24))

# %%
# Q-Q plot for transformed 'Wine Age'
stats.probplot(standardized_log_wineage, plot=plt);
ks_test_statistic_after_transformation_wineage, ks_p_value_after_transformation_wineage = stats.kstest(standardized_log_wineage, 'norm')
ks_test_statistic_after_transformation_wineage, ks_p_value_after_transformation_wineage
# Out:
# (np.float64(0.16286138059935473), np.float64(3.984719769809742e-201))

# %%
# Q-Q plot for transformed 'Price'
stats.probplot(df["rating"], plot=plt);

# %%
# Q-Q plot for transformed 'Price'
stats.probplot(standardized_log_rating, plot=plt);
ks_test_statistic_after_transformation_rating, ks_p_value_after_transformation_rating = stats.kstest(standardized_log_rating, 'norm')
ks_test_statistic_after_transformation_rating, ks_p_value_after_transformation_rating
# Out:
# (np.float64(0.06865504524743365), np.float64(6.281037602166536e-36))

# %%
df["Price_log_std"] = standardized_log_price
df["NumRatings_log_std"] = standardized_log_nratings
df["Wine_Age_log"] = standardized_log_wineage


df
# Out:
#             country                     winery  rating  numberofratings  \
# 0            France      Château La Providence     4.2              100
# 1            France         Château Mont-Redon     4.3              100
# 2             Italy                 Renzo Masi     3.9              100
# 3             Italy                 Cavalchina     3.5              100
# 4           Austria                Markowitsch     3.9              100
# ...             ...                        ...     ...              ...
# 8661  United States       Michael David Winery     3.8              994
# 8662          Italy                Le Mortelle     4.0              995
# 8663         France  Château Cambon La Pelouse     3.7              996
# 8664      Australia                Yellow Tail     3.5              998
# 8665      Argentina                  Salentein     3.4              999
#
#       price    year                          name_clean  \
# 0     95.00  2011.0                        pomerol 2011
# 1     15.50  2017.0                          lirac 2017
# 2      7.45  2015.0  erta e china rosso di toscana 2015
# 3      8.72  2019.0                      bardolino 2019
# 4     29.15  2016.0      ried scheibner pinot noir 2016
# ...     ...     ...                                 ...
# 8661  16.47  2016.0                6th sense syrah 2016
# 8662  20.09  2016.0     botrosecco maremma toscana 2016
# 8663  23.95  2010.0                     haut medoc 2010
# 8664   6.21  2019.0                         shiraz 2019
# 8665   7.88  2016.0    portillo cabernet sauvignon 2016
#
#                  region_clean          variety_ml  wine_age  Price_log_std  \
# 0                     pomerol      Bordeaux Blend      15.0       1.591272
# 1                       lirac         Rhône Blend       9.0      -0.378597
# 2                     toscana     Unspecified Red      11.0      -1.127167
# 3                   bardolino             Corvina       7.0      -0.970540
# 4                   carnuntum          Pinot Noir      10.0       0.295732
# ...                       ...                 ...       ...            ...
# 8661                     lodi               Syrah      10.0      -0.314696
# 8662          maremma toscana     Unspecified Red      10.0      -0.104045
# 8663               haut medoc      Bordeaux Blend      16.0       0.083966
# 8664  south eastern australia              Shiraz       7.0      -1.304689
# 8665                  tunuyan  Cabernet Sauvignon      10.0      -1.071645
#
#       NumRatings_log_std  Wine_Age_log
# 0              -0.465388      1.322606
# 1              -0.465388     -0.740746
# 2              -0.465388      0.059660
# 3              -0.465388     -1.720363
# 4              -0.465388     -0.322327
# ...                  ...           ...
# 8661            1.425051     -0.322327
# 8662            1.425881     -0.322327
# 8663            1.426710      1.588753
# 8664            1.428366     -1.720363
# 8665            1.429193     -0.322327
#
# [8658 rows x 13 columns]

# %% [markdown]
# ### FEATURE ENGINEERING
#
# #### X-y Split (Test/Train Split)
#
# Before feature scaling and normalising the dataset we need to divide the data into training and testing subsets to evaluate the model’s ability to generalize to unseen data. The training set is used to fit the model, while the test set is reserved for assessing its performance. An 80/20 split is applied, meaning 80% of the data is used for training and 20% for testing. This approach helps prevent overfitting and provides a more reliable estimate of model performance.

# %%
#first we must distinguish from features and target 
#X-y split; features = X, target = y
#Making sure features only takes numerical values 

features = df[["Price_log_std", "NumRatings_log_std", "Wine_Age_log"]]
target = df["rating"]

# %%
# Now we perform the division between train and test, we will reserve 20% of our data to Test

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20, random_state=0)
print(X_train.head())
print(y_train.head())
# Out:
#       Price_log_std  NumRatings_log_std  Wine_Age_log
# 3454      -0.284376           -1.496562     -0.740746
# 7764      -0.503255           -0.668407     -1.203286
# 5303      -0.416519           -1.152051     -0.740746
# 2881      -0.399122            0.280279      1.039277
# 914       -0.953409            1.649810     -0.740746
# 3454    3.5
# 7764    3.5
# 5303    4.0
# 2881    3.8
# 914     3.7
# Name: rating, dtype: float64

# %% [markdown]
# #### Feature Scaling (Normalising data)
#
# We need to adjust the range of features in a dataset to make sure they're all on a similar scale, which might help improve machine learning algorithms. We will do this through normalisation, but first, let's carry out a quick EDA to see the distribution of our variables and understand how close or far they are from normal distribution.
#
# ##### Checking if data is normally distributed

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

X_train_norm = pd.DataFrame(X_train_norm, columns=X_train.columns, index=X_train.index )
X_train_norm.head()

X_test_norm = pd.DataFrame(X_test_norm, columns=X_test.columns, index=X_test.index)
X_test_norm.head()
# Out:
#       Price_log_std  NumRatings_log_std  Wine_Age_log
# 8243       0.424804            0.530163      0.437560
# 5463       0.322883            0.427768      0.201029
# 3899       0.135701            0.031177      0.074352
# 5922       0.343127            0.442413      0.437560
# 6643       0.253133            0.125563      0.306484

# %% [markdown]
# ### MODEL TRAINING
#
# In this section, we train a K-Nearest Neighbours (K-NN) regression model to predict wine ratings based on the selected features. After preparing the dataset through feature engineering, train/test splitting, and feature scaling, the model is fitted using the training data. The trained model is then used to generate predictions for the test set, allowing us to evaluate its performance and assess how well it generalizes to unseen data.
#
# We will use KNeighborsRegression because our target (Ratings) is a continuous numerical value

# %% [markdown]
# #### Creating instance of the model KNN

# %%
#As a rule of thumb, a common starting point is to set k (n-neighbor) as the square root of the number of training samples
k = int(math.sqrt(len(X_train)))
print(k)

#We get 83 as a value but this is only a starting point lets keep trying until we get a k value that gives the lowest prediction error
for k in range(70, 101):
    model = KNeighborsRegressor(n_neighbors=k)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    print(k, mean_squared_error(y_test, preds))

knn = KNeighborsRegressor(n_neighbors=45)
# Out:
# 83
# 70 0.04041355634632605
# 71 0.0403642601796905
# 72 0.04032576697174464
# 73 0.04035935230862373
# 74 0.040330365592794584
# 75 0.040378274570182185
# 76 0.04041309444032166
# 77 0.040363504705606026
# 78 0.04035265615486348
# 79 0.04037051136546558
# 80 0.04034183115617781
# 81 0.04033672009667313
# 82 0.04033447713406046
# 83 0.04034597613023673
# 84 0.04033259247694457
# 85 0.04032500619321222
# 86 0.040364668749227145
# 87 0.04036035906152998
# 88 0.04039178659362891
# 89 0.04040535682474131
# 90 0.0403657058135888
# 91 0.04038483012812378
# 92 0.040388490228414745
# 93 0.04039866374438353
# 94 0.04040185763781799
# 95 0.0404128434615163
# 96 0.04044632251671959
# 97 0.04050239415016383
# 98 0.04049491623486365
# 99 0.04052544068062998
# 100 0.040533801385681294

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

accuracies = []
k_range = range(1, 101)  # test K from 1 to 100

for k in k_range:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_norm, y_train)
    accuracies.append(knn.score(X_test_norm, y_test))

# Find best k and maximum accuracy
max_accuracy = max(accuracies)
best_k = k_range[np.argmax(accuracies)]

print("Best k:", best_k)
print("Maximum accuracy:", max_accuracy)

# Plot the results
plt.figure(figsize=(50,6))
plt.plot(k_range, accuracies, marker='o', linestyle='--')

# Highlight the best point
plt.scatter(best_k, max_accuracy, s=200)
plt.text(best_k, max_accuracy, f'Best k={best_k}\nScore={max_accuracy:.3f}')

plt.title('KNN Accuracy vs Number of Neighbors (k)')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('R² Score')
plt.grid(True)

plt.show()
# Out:
# Best k: 45
# Maximum accuracy: 0.580036011401602

# %% [markdown]
# #### Fitting the model to our data

# %%
#Fit the model to our data 

print(X_train.columns)
knn.fit(X_train_norm, y_train)
# Out:
# Index(['Price_log_std', 'NumRatings_log_std', 'Wine_Age_log'], dtype='str')
# KNeighborsRegressor(n_neighbors=100)

# %% [markdown]
# #### Evaluating the model: R2 and Prediction Accuracy

# %%
pred = knn.predict(X_test_norm)
print(pred)
print(y_test)

print(f"The R2 of the model on the TEST set is: {knn.score(X_test_norm, y_test): .2f}")
print(f"The accuracy the model is {knn.score(X_test_norm, y_test)*100: .2f}%")
# Out:
# [4.181 4.096 3.679 ... 4.207 3.66  3.808]
# 8243    4.4
# 5463    4.2
# 3899    3.5
# 5922    3.9
# 6643    3.9
#        ...
# 5779    4.1
# 6680    4.3
# 3219    4.1
# 4046    3.4
# 289     4.0
# Name: rating, Length: 1732, dtype: float64
# The R2 of the model on the TEST set is:  0.58
# The accuracy the model is  57.52%

# %%
def run_knn_model(df, dummy_column, drop_columns, n_neighbors=47):

    import pandas as pd
    import numpy as np
    import math
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.neighbors import KNeighborsRegressor

    # One-hot encoding
    df_encoded = pd.get_dummies(df, columns=dummy_column, dtype=int)

    # Features and target
    features = df_encoded.drop(columns=drop_columns)
    target = df_encoded["rating"]

    # Train/test split
    X_train, X_test, y_train, y_test = train_test_split(
        features, target, test_size=0.20, random_state=0
    )

    # Scaling
    scaler = MinMaxScaler()
    scaler.fit(X_train)

    X_train_norm = scaler.transform(X_train)
    X_test_norm = scaler.transform(X_test)

    # Convert back to dataframe
    X_train_norm = pd.DataFrame(X_train_norm, columns=X_train.columns, index=X_train.index)
    X_test_norm = pd.DataFrame(X_test_norm, columns=X_test.columns, index=X_test.index)

    # Train KNN
    knn = KNeighborsRegressor(n_neighbors=n_neighbors)
    knn.fit(X_train_norm, y_train)

    # Suggested K value
    k_suggested = int(math.sqrt(len(X_train)))

    # Model performance
    r2 = knn.score(X_test_norm, y_test)

    print("Suggested K:", k_suggested)
    print(f"R² on TEST set: {r2:.2f}")
    print(f"Accuracy: {r2*100:.2f}%")

    return knn, r2

# %% [markdown]
# ### MODEL TRAINING USING CATEGORICAL VARIABLES
#
# #### Numerical Variables + Country
#
# Since country is a categorical variable it cannot be included as a feature until we turn it into a numerical variable. In order to do this we have to carry out one hot encoding

# %%
knn_country, score_country = run_knn_model(
    df=df,
    dummy_column=["country"],
    drop_columns=["name_clean","rating","winery","region_clean","price","numberofratings", "variety_ml", "wine_age"],
    n_neighbors=45
)
# Out:
# Suggested K: 83
# R² on TEST set: 0.55
# Accuracy: 55.33%

# %% [markdown]
# #### Numerical Variables + All Categorical Variables
#
# Here we will one hot encode all categorical variables (variety, winery, region, country, name) and add them as features.

# %%
knn_all, score_all = run_knn_model(
    df=df,
    dummy_column=["country", "region_clean", "name_clean", "winery", "variety_ml", "year"],
    drop_columns= "rating",
    n_neighbors=45
)
# Out:
# Suggested K: 83
# R² on TEST set: 0.47
# Accuracy: 47.07%

# %% [markdown]
# #### Checking which categories are the most useful
#
# After including all categorical variables in our model the R² of the model decreased significantly, thus, it is useful for us to see which categories are most useful and which ones could potentially be adding more noise limiting our model

# %%
categorical_cols = df.select_dtypes(include=["object", "category"]).columns

results = []

for col in categorical_cols:

    df_temp = df.copy()

    # Keep only numeric columns + the categorical variable being tested
    numeric_cols = df_temp.select_dtypes(include=[np.number]).columns
    df_temp = df_temp[list(numeric_cols) + [col]]

    # One-hot encode that variable
    df_temp = pd.get_dummies(df_temp, columns=[col], dtype=int)

    # Log transform
    df_temp["price"] = np.log1p(df_temp["price"])
    df_temp["numberofratings"] = np.log1p(df_temp["numberofratings"])

    # Features / target
    X = df_temp.drop(columns=["rating"])
    y = df_temp["rating"]

    # Train/test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.20, random_state=0
    )

    # Scaling
    scaler = MinMaxScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Train KNN
    knn = KNeighborsRegressor(n_neighbors=47)
    knn.fit(X_train, y_train)

    score = knn.score(X_test, y_test)

    results.append((col, score))


results_df = pd.DataFrame(results, columns=["Variable", "R2"])
results_df = results_df.sort_values(by="R2", ascending=False)

print(results_df)
# Out:
# /var/folders/rj/tlxb_lp50s7f22bllq0n47rw0000gn/T/ipykernel_38150/3137255862.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=["object", "category"]).columns
#        Variable        R2
# 1        winery  0.580713
# 2    name_clean  0.577330
# 0       country  0.556384
# 4    variety_ml  0.544311
# 3  region_clean  0.499490

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.bar(results_df["Variable"], results_df["R2"])

plt.xlabel("Variable")
plt.ylabel("R² Score")
plt.title("Model Performance by Variable")
plt.xticks(rotation=45)

plt.show()

# %%
importance_df = df[numeric_cols].corrwith(df["rating"]).abs().sort_values(ascending=False)
importance_df
# Out:
# rating                1.000000
# Price_log_std         0.754682
# price                 0.451251
# Wine_Age_log          0.363087
# wine_age              0.343491
# year                  0.343491
# NumRatings_log_std    0.109285
# numberofratings       0.070317
# dtype: float64

# %% [markdown]
# #### Numerical Variables + Winery
#
# Winery was the one of the most useful categories so let's see how our predicition accuracy changes when we only inlclude that categorical variable as a feature

# %%
knn_country, score_country = run_knn_model(
    df=df,
    dummy_column=["winery"],
    drop_columns=["name_clean","rating","country","region_clean","price","numberofratings", "variety_ml", "wine_age"],
    n_neighbors=45
)
# Out:
# Suggested K: 83
# R² on TEST set: 0.58
# Accuracy: 57.84%

# %% [markdown]
# #### Numerical Variables + Variety
#
# Even though variety was one of the least useful variables for our model, it is one of the categorical variables we are most interest in so lets evaluate how it changes our model's accuracy

# %%
knn_variety, score = run_knn_model(
    df=df,
    dummy_column=["variety_ml"],
    drop_columns=["name_clean","rating","winery","country","region_clean","price","numberofratings", "year"],
    n_neighbors=45
)
# Out:
# Suggested K: 83
# R² on TEST set: 0.54
# Accuracy: 54.15%

# %% [markdown]
# Model: KNeighborsRegressor
# k: 72
# Preprocessing: MinMaxScaler
# Goal: Predict a continuous value

# %%
df.groupby("winery")["rating"].agg("count").sort_values(ascending=False)
# Out:
# winery
# Errazuriz                 40
# Gaja                      32
# Torres                    31
# M. Chapoutier             31
# Château de Saint Cosme    31
#                           ..
# Massimo Rattalino          1
# Château Val d'Arenc        1
# Masseria del Feudo         1
# Château Victoria           1
# Ökonomierat Rebholz        1
# Name: rating, Length: 2713, dtype: int64
